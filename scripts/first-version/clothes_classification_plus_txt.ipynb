# %%
#!/usr/bin/env python
# coding: utf-8

# In[9]:


import os
import shutil

### Dico avec les bounding boxes, modifier label en fonction des classes qu'on veut

dico = {'Denim' : ["0 0.520408 0.620594 0.619666 0.372913"],
       'Jackets' : ["1 0.516698 0.321892 0.560297 0.343228"],
       'Pants' :["0 0.520408 0.620594 0.619666 0.372913"], 
       'Sweaters':["1 0.516698 0.321892 0.560297 0.343228"],
       'Rompers_Jumpsuits':['0 0.498145 0.525046 0.448980 0.708720'],
       'Cardigans':["1 0.516698 0.321892 0.560297 0.343228"],
       'Blouses_Shirts':["1 0.516698 0.321892 0.560297 0.343228"],
       'Shorts':["0 0.524119 0.548237 0.404453 0.135436"],
       'Jackets_Coats':["1 0.516698 0.321892 0.560297 0.343228"],
       'Skirts':["0 0.524119 0.548237 0.404453 0.135436"],
       'Suiting': ['0 0.498145 0.525046 0.448980 0.708720'],
       'Jackets_Vests':["1 0.516698 0.321892 0.560297 0.343228"],
       'Leggings':["0 0.520408 0.620594 0.619666 0.372913"],
       'Graphic_Tees':["1 0.516698 0.321892 0.560297 0.343228"],
        'Shirts_Polos':["1 0.516698 0.321892 0.560297 0.343228"],
        'Tees_Tanks':["1 0.516698 0.321892 0.560297 0.343228"],
        'Sweatshirts_Hoodies':["1 0.516698 0.321892 0.560297 0.343228"],
        'Dresses' : ['0 0.498145 0.525046 0.448980 0.708720']
       }

### on va supprimer les images qui ne nous intéressent pas

### toutes les classes contenues
dest_folders = ['Denim','Jackets','Pants','Sweaters','Rompers_Jumpsuits','Cardigans','Blouses_Shirts',
                'Shorts','Jackets_Coats','Skirts','Suiting','Jackets_Vests','Leggings','Graphic_Tees',
                'Shirts_Polos','Tees_Tanks','Sweatshirts_Hoodies','Dresses']

### les classes qu'on veut garder
relevant = ['Denim','Jackets','Pants','Sweaters','Cardigans','Blouses_Shirts',
            'Jackets_Coats','Jackets_Vests','Leggings','Graphic_Tees','Shirts_Polos',
            'Tees_Tanks','Sweatshirts_Hoodies']

# %%
### supprimer classes qui n'appartiennent pas aux labels voulus

folder_path = '/Users/avicenne/Documents/python/deep_fashion/datasets/data_train/images/train'
for filename in os.listdir(folder_path):
    attribute = filename.split('-')[1]
    if attribute not in relevant:
        os.remove(os.path.join(folder_path, filename))

# %%
### compter train
count = {}
folder_path = '/Users/avicenne/Documents/python/deep_fashion/datasets/data_train/images/train'
for filename in os.listdir(folder_path):
    attribute = filename.split('-')[1]
    if attribute not in count:
        count[attribute] = 1
    else:
        count[attribute] += 1
count

# %%
### dossier val

folder_path = '/Users/avicenne/Documents/python/deep_fashion/datasets/data_train/images/val'
for filename in os.listdir(folder_path):
    attribute = filename.split('-')[1]
    if attribute not in relevant:
        os.remove(os.path.join(folder_path, filename))

# %%
### on ajoute deux bounding box pour chaque classe : shirt et pant

nv_dico = {'Denim' : ["1 0.509381 0.309568 0.348968 0.296435\n0 0.471857 0.629456 0.348968 0.328330"],
       'Jackets' : ["2 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Pants' :["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"], 
       'Sweaters':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Rompers_Jumpsuits':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Cardigans':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Blouses_Shirts':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Shorts':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Jackets_Coats':["2 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Skirts':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Suiting': ["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Jackets_Vests':["2 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Leggings':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
       'Graphic_Tees':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
        'Shirts_Polos':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
        'Tees_Tanks':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
        'Sweatshirts_Hoodies':["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"],
        'Dresses' : ["0 0.520408 0.620594 0.619666 0.372913 \n1 0.516698 0.321892 0.560297 0.343228"]
       }

bounding_box = ["1 0.509381 0.309568 0.348968 0.296435\n0 0.471857 0.629456 0.348968 0.328330", 
                "1 0.545028 0.326454 0.457786 0.315197\n0 0.496248 0.659475 0.352720 0.324578",
                "1 0.513133 0.313321 0.393996 0.281426\n0 0.537523 0.625704 0.345216 0.339587"]

# %%
### on copie le nom des images en fichier texte avec le numéro de label et la position de la bounding box, vers val
import numpy as np

folder_path = '/Users/avicenne/Documents/python/deep_fashion/datasets/data_train/images/val'
detination = '/Users/avicenne/Documents/python/deep_fashion/datasets/data_train/labels/val'
    
for filename in os.listdir(folder_path):
    attribute = filename.split('-')[1]
    # Créer un nom de fichier texte correspondant
    text_filename = os.path.splitext(filename)[0] + '.txt'
    text_file_path = os.path.join(detination, text_filename)

    # Écrire l'information dans le fichier texte
    with open(text_file_path, 'w') as file:
        r = np.random.rand()
        if r<0.33:
            file.write(bounding_box[0])
        elif 0.66>r>=0.33 :
            file.write(bounding_box[1])
        else:
            file.write(bounding_box[2])

# %%
### on copie le nom des images en fichier texte avec le numéro de label et la position de la bounding box, vers train

folder_path = '/Users/avicenne/Documents/python/deep_fashion/datasets/data_train/images/train'
detination = '/Users/avicenne/Documents/python/deep_fashion/datasets/data_train/labels/train'
    
for filename in os.listdir(folder_path):
    attribute = filename.split('-')[1]
    # Créer un nom de fichier texte correspondant
    text_filename = os.path.splitext(filename)[0] + '.txt'
    text_file_path = os.path.join(detination, text_filename)

    # Écrire l'information dans le fichier texte
    with open(text_file_path, 'w') as file:
        r = np.random.rand()
        if r<0.33:
            file.write(bounding_box[0])
        elif 0.66>r>=0.33 :
            file.write(bounding_box[1])
        else:
            file.write(bounding_box[2])
